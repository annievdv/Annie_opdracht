# %% [markdown]
# <a href="https://colab.research.google.com/github/annievdv/Annie_opdracht/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files

#print("Please upload the file now. A file browser window will appear.")
#uploaded = files.upload()

# Lees de data
costs_df=pd.read_csv('https://raw.githubusercontent.com/annievdv/Annie_opdracht/refs/heads/main/levelized-cost-of-energy.csv')

print("cost data ")
display(costs_df.head())
# Out:
# cost data
#       Entity Code  Year  Bioenergy  Geothermal  Offshore wind  \
# 0  Argentina  ARG  1995        NaN         NaN            NaN
# 1  Argentina  ARG  1997        NaN         NaN            NaN
# 2  Argentina  ARG  2008        NaN         NaN            NaN
# 3  Argentina  ARG  2009        NaN         NaN            NaN
# 4  Argentina  ARG  2012        NaN         NaN            NaN
#
#    Solar photovoltaic  Concentrated solar power  Hydropower  Onshore wind
# 0                 NaN                       NaN         NaN      0.287333
# 1                 NaN                       NaN         NaN      0.146460
# 2                 NaN                       NaN         NaN      0.563346
# 3                 NaN                       NaN         NaN      0.317437
# 4                 NaN                       NaN         NaN      0.122855

# %%
import matplotlib.pyplot as plt

df_filtered = fuel_df[fuel_df['country'].str.contains("World|European Union") == False].reset_index(drop=True)

# Filter for the year 2021 to find the largest emitters in that year
df_2021 = df_filtered[df_filtered['year'] == 2021]

# Use 'greenhouse_gas_emissions' as the column for CO2 emissions
largest_countries_2021 = df_2021.nlargest(10, 'greenhouse_gas_emissions')

# Get the list of top 10 country names
top_10_countries = largest_countries_2021['country'].tolist()

# Filter the original df_filtered (containing all years) for these top 10 countries
df_plot = df_filtered[df_filtered['country'].isin(top_10_countries)]

# Plotting the data over time
plt.figure(figsize=[12, 8])
for country in top_10_countries:
    country_data = df_plot[df_plot['country'] == country]
    plt.plot(country_data['year'], country_data['greenhouse_gas_emissions'], label=country)

plt.title('The Carbon Dioxide Emissions Over Time (Top 10 Countries in 2021)')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions')
plt.legend()
plt.grid(True)
plt.show()
