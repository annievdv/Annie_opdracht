# %% [markdown]
# <a href="https://colab.research.google.com/github/annievdv/Annie_opdracht/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Lees de data
df=pd.read_csv('https://raw.githubusercontent.com/annievdv/Annie_opdracht/refs/heads/main/levelized-cost-of-energy.csv')

print("cost data ")
display(df.head())
# Out:
# cost data
#       Entity Code  Year  Bioenergy  Geothermal  Offshore wind  \
# 0  Argentina  ARG  1995        NaN         NaN            NaN
# 1  Argentina  ARG  1997        NaN         NaN            NaN
# 2  Argentina  ARG  2008        NaN         NaN            NaN
# 3  Argentina  ARG  2009        NaN         NaN            NaN
# 4  Argentina  ARG  2012        NaN         NaN            NaN
#
#    Solar photovoltaic  Concentrated solar power  Hydropower  Onshore wind
# 0                 NaN                       NaN         NaN      0.287333
# 1                 NaN                       NaN         NaN      0.146460
# 2                 NaN                       NaN         NaN      0.563346
# 3                 NaN                       NaN         NaN      0.317437
# 4                 NaN                       NaN         NaN      0.122855

# %%
df_filtered = df[df['Entity'].str.contains("World|European Union") == False].reset_index(drop=True)

xOnshoreWind = 'Onshore wind'

# Filter df_filtered for the year 2024 to find the largest emitters in that year
df_for_ranking = df_filtered[df_filtered['Year'] == 2024]

# Drop rows where 'Onshore Wind' is NaN for ranking purposes
df_for_ranking = df_for_ranking.dropna(subset=['Entity', xOnshoreWind])

# Use 'Onshore Wind' as the column to find the largest countries (excluding World/EU)
largest_countries = df_for_ranking.nlargest(10, xOnshoreWind)

# Get the list of top 10 country names
top_10_countries = largest_countries['Entity'].tolist()

# Filter the original df_filtered (containing all years, but no World/EU) for these top 10 countries
df_plot = df_filtered[df_filtered['Entity'].isin(top_10_countries)]

# Plotting the data over time
plt.figure(figsize=[12, 8])
for country in top_10_countries:
    country_data = df_plot[df_plot['Entity'] == country]
    plt.plot(country_data['Year'], country_data[xOnshoreWind], label=country, marker='o', markersize=4)
    #plt.scatter(df_for_ranking['Year'], df_for_ranking[xOnshoreWind])
# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Onshore wind')

plt.title('Niet fossiele brandstof')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
